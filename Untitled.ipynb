# %%
#Develp a program to display gray scale image using read and write operation
import cv2
img=cv2.imread('blue.jpg',0)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#develop a program to display the image using mathplotlib
import matplotlib.image as mping
import matplotlib.pyplot as plt
img=mping.imread('leaf1.jpg')
plt.imshow(img)

# %%
#Develop a program to perform Linear Transformation a) Rotation b) Scaling
from PIL import Image
img=Image.open('butterfly1.jpg')
img=img.rotate(180)
img.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Develop a program to convert Colorstring to RGB color value
from PIL import ImageColor
from PIL import Image
img=Image.new('RGB',(200,400),(255,255,0))
img.show()

# %%
#Write a program to create image using colors
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('plant1.jpg')
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img)
plt.show()

# %%
#Write a program to display the image attributes
from PIL import Image
from PIL import Image
img=Image.open('plant1.jpg')
print('Filename:',img.filename)
print('Format:',img.format)
print('Mode:',img.mode)
print('Size:',img.size)
print('Width:',img.width)
print('Height:',img.height)
img.close()
# Out:
# Filename: plant1.jpg
# Format: JPEG
# Mode: RGB
# Size: (284, 177)
# Width: 284
# Height: 177

# %%
#Resize the original image
import cv2
import cv2
img=cv2.imread('blue.jpg')
print('original image length width',img.shape)
cv2.imshow('original image',img)
cv2.waitKey(0)
#to show resized image
imgresize=cv2.resize(img,(150,160))
cv2.imshow('Resized image',imgresize)
print('Resized image length width',imgresize.shape)
cv2.waitKey(0)
# Out:
# original image length width (1500, 1000, 3)
# Resized image length width (160, 150, 3)
# -1

# %%
#Convert the original image to gray scale and then to binary
import cv2
import cv2
#read the image file
img=cv2.imread("leaf1.jpg")
cv2.imshow("RGB",img)
cv2.waitKey(0)
#gray scale
img=cv2.imread('leaf1.jpg',0)
cv2.imshow("Gray",img)
cv2.waitKey(0)
#Binary image
ret,bw_img=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
cv2.imshow("Binary",bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Develop a program to visualize the image using various Colorspaces
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('butterfly1.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
from skimage import io
import matplotlib.pyplot as plt
url='https://images.hindustantimes.com/rf/image_size_630x354/HT/p2/2019/08/08/Pictures/_6bda0940-b9ad-11e9-98cb-e738ad509720.jpg'

image=io.imread(url)
plt.imshow(image)
plt.show()

# %%
from skimage import io
import matplotlib.pyplot as plt
url='https://assets.goal.com/v3/assets/bltcc7a7ffd2fbf71f5/bltc46c24cf519daecc/60df72b928853322c5823d7f/debc6f7ab23f69c656a6e7eb7d6912335f0d75f7.jpg?quality=80&width=620&format=pjpg&auto=webp'

image=io.imread(url)
plt.imshow(image)
plt.show()

# %%
import cv2
import matplotlib.image as mping
import matplotlib.pyplot as plt
img=mping.imread('bb1.jpg')
plt.imshow(img)
plt.show()

# %%
hsv_img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
light_orange=(1,190,200)
dark_orange=(18,255,255)
mask=cv2.inRange(hsv_img,light_orange,dark_orange)
result=cv2.bitwise_and(img,img,mask=mask)
plt.subplot(1,2,1)
plt.imshow(mask,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(result)
plt.show()

# %%
light_white=(0,0,200)
dark_white=(145,60,255)
mask_white=cv2.inRange(hsv_img,light_white,dark_white)
result_white=cv2.bitwise_and(img,img,mask=mask_white)
plt.subplot(1,2,1)
plt.imshow(mask_white,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(result_white)
plt.show()

# %%
final_mask=mask+mask_white
final_result=cv2.bitwise_and(img,img,mask=final_mask)
plt.subplot(1,2,1)
plt.imshow(final_mask,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(final_result)
plt.show()

# %%
blur=cv2.GaussianBlur(final_result,(7,7),0)
plt.imshow(blur)
plt.show()

# %%
import cv2
import matplotlib.image as mping
import matplotlib.pyplot as plt

#Read file
img1=cv2.imread('bb1.jpg')
img2=cv2.imread('leaf1.jpg')

#numpy add
fimg1 = img1 + img2
plt.imshow(fimg1)
plt.show()

#saving
cv2.imwrite('output.jpg',fimg1)
fimg2 = img1 - img2
plt.imshow(fimg2)
plt.show()
#saving
cv2.imwrite('output.jpg',fimg2)
fimg3 = img1 * img2
plt.imshow(fimg3)
plt.show()
#saving
cv2.imwrite('output.jpg',fimg3)
fimg4 = img1 / img2
plt.imshow(fimg4)
plt.show()
#saving
cv2.imwrite('output.jpg',fimg4)
# Out:
# C:\Users\Central Computer Lab\AppData\Local\Temp\ipykernel_8172\3039024910.py:26: RuntimeWarning: divide by zero encountered in true_divide
#   fimg4 = img1 / img2
# C:\Users\Central Computer Lab\AppData\Local\Temp\ipykernel_8172\3039024910.py:26: RuntimeWarning: invalid value encountered in true_divide
#   fimg4 = img1 / img2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# True
